# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

client = pymongo.MongoClient("mongodb+srv://analytics:analytics-password@mflix.dixfz.mongodb.net/mflix?retryWrites=true&w=majority")

pipeline = [
    {'$match': {'language': 'English, Korean, French'}}
]



clear_output()
pprint.pprint(list(client.analytics.mflix.aggregate(pipeline)))
# Out:
# [{'_id': ObjectId('61873da96727dd7d92fc5e28'),
#   'awards': '',
#   'cast': 'Jae-hyeon Jo, Dong-jik Jang, Ryun Jang, Sasha Rucavina',
#   'country': 'South Korea',
#   'director': 'Ki-duk Kim',
#   'fullplot': 'Two Korean ex-pats meet in Paris by chance encounter. One a '
#               'petty thief and wannabe artist/painter (Chong-Hae), the other a '
#               'tough guy (Hong San). Hong San saves Chong-Hae from a gang of '
#               'thugs and the two become friends. Seizing an opportunity, '
#               'Chong-Hae and Hong San perform martial arts stunts on the '
#               'streets for money. A French mobster spots them and recruits the '
#               'duo as hit men. While in Paris Chong-Hae falls in love with a '
#               'statue-performer and Hong San yearns for the affections of a '
#               'local peep-show stripper. After much backstabbing and being '
#               'caught-up in murder; the duo find themselves at war with their '
#               'mobster recruiters and each other.',
#   'genre': 'Comedy, Crime, Drama',
#   'imbdID': 190882,
#   'imbdRating': 6.4,
#   'imdbVotes': 599,
#   'language': 'Korean, French',
#   'lastupdated': '26:35.5',
#   'metacritic': '',
#   'plot': 'Two Korean ex-pats meet in Paris by chance encounter. One a petty '
#           'thief and wannabe artist/painter (Chong-Hae), the other a tough guy '
#           '(Hong San). Hong San saves Chong-Hae from a gang of ...',
#   'poster': '',
#   'rating': '',
#   'released': '25/10/97',
#   'runtime': '105 min',
#   'title': 'Wild Animals',
#   'type': 'movie',
#   'writer': 'Ki-duk Kim',
#   'year': 1997},
#  {'_id': ObjectId('61873db26727dd7d92fc8172'),
#   'awards': '1 win & 2 nominations.',
#   'cast': 'Jin-ho Choi, Ja-Hyeon Chu, Jeong-min Hwang, Won-jae Kang',
#   'country': 'South Korea',
#   'director': 'Ho Choi',
#   'fullplot': 'The underworld of pushers, addicts, cops, and mobsters in '
#               'Buson. Sang-do is a pusher, selling meth, abstaining from using '
#               'it, living the high life, and, passing on information to the '
#               'police. He enters into a special one-year deal with Lieutenant '
#               'Doh, a loose canon on the force, seeking revenge against a mob '
#               "boss who killed his partner and fled to China. Word is he's "
#               "back, and Doh wants Sang-do's help. Perhaps Sang-do's uncle, a "
#               'meth manufacturer, can help. Along the way, Sang-do tries to '
#               'rescue an old girlfriend from the depths of addiction and '
#               "prostitution, but she may be unable to stay straight. Doh's "
#               "nemesis is slippery. Can there be any victors on Buson's docks?",
#   'genre': 'Action, Crime, Drama',
#   'imbdID': 816437,
#   'imbdRating': 6.4,
#   'imdbVotes': 507,
#   'language': 'Korean, French',
#   'lastupdated': '11:54.3',
#   'metacritic': '',
#   'plot': 'The underworld of pushers, addicts, cops, and mobsters in Buson. '
#           'Sang-do is a pusher, selling meth, abstaining from using it, living '
#           'the high life, and, passing on information to the police...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDY3OTk2NTU4OF5BMl5BanBnXkFtZTcwMTQxNzU0MQ@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '26/4/06',
#   'runtime': '117 min',
#   'title': 'Bloody Tie',
#   'type': 'movie',
#   'writer': 'Ho Choi, Deok-won Yun',
#   'year': 2006},
#  {'_id': ObjectId('61873db26727dd7d92fc81a1'),
#   'awards': '1 win & 2 nominations.',
#   'cast': 'Jin-ho Choi, Ja-Hyeon Chu, Jeong-min Hwang, Won-jae Kang',
#   'country': 'South Korea',
#   'director': 'Ho Choi',
#   'fullplot': 'The underworld of pushers, addicts, cops, and mobsters in '
#               'Buson. Sang-do is a pusher, selling meth, abstaining from using '
#               'it, living the high life, and, passing on information to the '
#               'police. He enters into a special one-year deal with Lieutenant '
#               'Doh, a loose canon on the force, seeking revenge against a mob '
#               "boss who killed his partner and fled to China. Word is he's "
#               "back, and Doh wants Sang-do's help. Perhaps Sang-do's uncle, a "
#               'meth manufacturer, can help. Along the way, Sang-do tries to '
#               'rescue an old girlfriend from the depths of addiction and '
#               "prostitution, but she may be unable to stay straight. Doh's "
#               "nemesis is slippery. Can there be any victors on Buson's docks?",
#   'genre': 'Action, Crime, Drama',
#   'imbdID': 816437,
#   'imbdRating': 6.4,
#   'imdbVotes': 507,
#   'language': 'Korean, French',
#   'lastupdated': '03:57.7',
#   'metacritic': '',
#   'plot': 'The underworld of pushers, addicts, cops, and mobsters in Buson. '
#           'Sang-do is a pusher, selling meth, abstaining from using it, living '
#           'the high life, and, passing on information to the police...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDY3OTk2NTU4OF5BMl5BanBnXkFtZTcwMTQxNzU0MQ@@._V1_SX300.jpg',
#   'rating': '',
#   'released': '26/4/06',
#   'runtime': '117 min',
#   'title': 'Bloody Tie',
#   'type': 'movie',
#   'writer': 'Ho Choi, Deok-won Yun',
#   'year': 2006},
#  {'_id': ObjectId('61873db26727dd7d92fc83c3'),
#   'awards': '',
#   'cast': 'Jae-yeong Jeong, Jun-ho Jeong, Seung-ryong Ryu, Won-tae Choi',
#   'country': 'South Korea',
#   'director': 'Jin Jang',
#   'fullplot': 'An eccentric but faithful mafia, Chi-sung is sent to prison for '
#               'his part in a gang fight. But when his parents are attacked by '
#               'a rival mob and his own people take no action, he realizes that '
#               'a decade of loyalty towards the gang has become futile. '
#               'Determined to confront his own boss, he finds a way to escape '
#               'from prison with his fellow inmates. Meanwhile, his friend '
#               'Joo-joong is given the task to stop Chi-sung, forcing him to '
#               'choose between the bond of friendship and loyalty towards the '
#               'gang.',
#   'genre': 'Comedy',
#   'imbdID': 891488,
#   'imbdRating': 6.6,
#   'imdbVotes': 286,
#   'language': 'Korean, French',
#   'lastupdated': '02:33.1',
#   'metacritic': '',
#   'plot': 'An eccentric but faithful mafia, Chi-sung is sent to prison for his '
#           'part in a gang fight. But when his parents are attacked by a rival '
#           'mob and his own people take no action, he realizes ...',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTYwNTAyNDM4MV5BMl5BanBnXkFtZTgwNjMyODc1MjE@._V1_SX300.jpg',
#   'rating': '',
#   'released': '19/10/06',
#   'runtime': '126 min',
#   'title': 'Righteous Ties',
#   'type': 'movie',
#   'writer': 'Jin Jang',
#   'year': 2006},
#  {'_id': ObjectId('61873db56727dd7d92fc8cd9'),
#   'awards': '1 win.',
#   'cast': 'Ji-hun Ju, Jae-wook Kim, Ah In Yoo, Ji-ho Choi',
#   'country': 'South Korea',
#   'director': 'Kyu-dong Min',
#   'fullplot': 'Jin-hyeok opens a cake shop in an old antique shop, hiring '
#               "Seun-woo, Korea's best pastry chef, who fell in love with him "
#               'in high school. Also there, are Soo-young, crushing on '
#               "Seun-woo, ex-boxer Gi-beom, and Seun-woo's French ex-boyfriend.",
#   'genre': 'Comedy, Drama',
#   'imbdID': 1205551,
#   'imbdRating': 7.2,
#   'imdbVotes': 815,
#   'language': 'Korean, French',
#   'lastupdated': '13:23.3',
#   'metacritic': '',
#   'plot': 'Jin-hyeok opens a cake shop in an old antique shop, hiring '
#           "Seun-woo, Korea's best pastry chef, who fell in love with him in "
#           'high school. Also there, are Soo-young, crushing on Seun-woo, '
#           "ex-boxer Gi-beom, and Seun-woo's French ex-boyfriend.",
#   'poster': '',
#   'rating': '',
#   'released': '13/11/08',
#   'runtime': '107 min',
#   'title': 'Antique',
#   'type': 'movie',
#   'writer': '',
#   'year': 2008}]
