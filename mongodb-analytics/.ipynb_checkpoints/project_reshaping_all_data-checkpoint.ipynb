# %%
import pymongo
from pymongo import MongoClient
import pprint
from IPython.display import clear_output

client = pymongo.MongoClient("mongodb+srv://analytics:analytics-password@mflix.dixfz.mongodb.net/mflix?retryWrites=true&w=majority")

pipeline = [
    {
        '$limit': 100
    },
    {
        '$project': {
            'title': 1,
            'year': 1,
            'directors': {'$split': ["$director", ", "]},
            'actors': {'$split': ["$cast", ", "]},
            'genres': {'$split': ["$genre", ", "]},
            'languages': {'$split': ["$language", ", "]},
            'countries': {'$split': ["$country", ", "]},
            'plot': 1,
            'fullPlot': "$fullplot",
            'rated': "$rating",
            'released': 1,
            'runtime': 1,
            'poster': 1,
            'imdb': {
                'id': "$imdbID",
                'rating': "$imdbRating",
                'votes': "$imdbVotes"
                },
            'metacritic': 1,
            'awards': 1,
            'type': 1,
            'lastUpdated': "$lastupdated",
#             {'$addFields': {
#                 'Script Writer': {
#                     '$ifNull': [
#                         "$writer", 
#                         "Author unknown"
#                     ]
#                 }
#             }}
        }
    },
    {
        '$out': "movies_scratch"
    }
]



clear_output()
pprint.pprint(list(client.analytics.mflix.aggregate(pipeline)))
# Out:
#   File "<ipython-input-20-bebeeca795fe>", line 43
#     }},
#       ^
# SyntaxError: invalid syntax
